# %% [markdown]
# <a href="https://colab.research.google.com/github/akhil2630/python-tasks/blob/main/python_task_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Matplotlib

# %% [markdown]
# ##1. 1. Write a Python program to draw a line with suitable label in the x axis, y axis and a title. The code snippet gives the output shown in the following screenshot:
#
# ![image.png](data:image/png;base64,...)

# %%
import matplotlib.pyplot as plt
x=range(50)
y=[i*3 for i in x]
plt.plot(x,y)
plt.ylim(0,160)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Draw a line')
plt.show()

# %% [markdown]
# ##2 Write a Python program to draw a line using given axis values with suitable label in the x axis , y axis and a title. The code snippet gives the output shown in the following screenshot:
#
# ![image.png](data:image/png;base64,...)

# %%
import matplotlib.pyplot as plt
x=[1,2, 3]
y=[2,4,1]
plt.plot(x,y)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Sample graph!')
plt.show()

# %% [markdown]
# ##3. Write a Python program to draw line charts of the financial data of Alphabet Inc. between October 3, 2016 to October 7, 2016.
# ```
# Sample Financial data (fdata.csv):
# Date,Open,High,Low,Close
# 10-03-16,774.25,776.065002,769.5,772.559998
# 10-04-16,776.030029,778.710022,772.890015,776.429993
# 10-05-16,779.309998,782.070007,775.650024,776.469971
# 10-06-16,779,780.47998,775.539978,776.859985
# 10-07-16,779.659973,779.659973,770.75,775.080017
# The code snippet gives the output shown in the following screenshot:
# ```

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
import matplotlib.pyplot as plt
data = {
    "Date": ["10-03-16", "10-04-16", "10-05-16", "10-06-16", "10-07-16"],
    "Open": [774.25, 776.030029, 779.309998, 779, 779.659973],
    "High": [776.065002, 778.710022, 782.070007, 780.47998, 779.659973],
    "Low": [769.5, 772.890015, 775.650024, 775.539978, 770.75],
    "Close": [772.559998, 776.429993, 776.469971, 776.859985, 775.080017]
}
df=pd.DataFrame(data)
plt.plot(df['Date'],df['Open'],label='Open',color='blue')
plt.plot(df['Date'],df['High'],label='High',color='orange')
plt.plot(df['Date'],df['Low'],label='Low',color='green')
plt.plot(df['Date'],df['Close'],label='Close',color='red')
plt.legend()
plt.show()

# %% [markdown]
# ##4.  Write a Python program to plot two or more lines with legends, different widths and colors. The code snippet gives the output shown in the following screenshot:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import matplotlib.pyplot as plt
x=[10,20,30]
y1=[20,40,10]
y2=[40,10,30]
plt.plot(x,y1,label='Line1-width-3',color='blue',linewidth=3)
plt.plot(x,y2,label='Line2-width-5',color='red',linewidth=5)
plt.title('Two or more lines with differnt widths and colors with suitable legends')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.legend()
plt.show()

# %% [markdown]
# ##5 Write a Python program to plot quantities which have an x and y position. The code snippet gives the output shown in the following screenshot:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import matplotlib.pyplot as plt
x1 = [2,3,5,6,8]
y1 = [1,5,10,18,20]
x2 = [3,4,6,7,9]
y2 = [2,6,11,20,22]
plt.scatter(x1,y1,color='blue',marker='*')
plt.scatter(x2,y2,color='red',marker='o')
plt.show()

# %% [markdown]
# ##6.  Write a Python programming to display a bar chart of the popularity of programming Languages.
# ```
# Sample data:
# Programming languages: Java, Python, PHP, JavaScript, C#, C++
# Popularity: 22.2, 17.6, 8.8, 8, 7.7, 6.7
# The code snippet gives the output shown in the following screenshot:
# ```

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import matplotlib.pyplot as plt
languages=['Java', 'Python','PHP','JavaScript','C#','C++']
popularity=[22.2, 17.6, 8.8, 8, 7.7, 6.7]
plt.bar(languages,popularity,color='blue')
plt.title('Popularity of programming language \n Worldwide Oct 2017 compared to ayear ago')
plt.xlabel('Languages')
plt.ylabel('Popularity')
plt.grid(True)
plt.show()

# %% [markdown]
# ##7.  Write a Python programming to display a horizontal bar chart of the popularity of programming Languages.
# ```
# Sample data:
# Programming languages: Java, Python, PHP, JavaScript, C#, C++
# Popularity: 22.2, 17.6, 8.8, 8, 7.7, 6.7
# The code snippet gives the output shown in the following screenshot:
# ```

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import matplotlib.pyplot as plt
languages=['Java', 'Python','PHP','JavaScript','C#','C++']
popularity=[22.2, 17.6, 8.8, 8, 7.7, 6.7]
plt.barh(languages,popularity,color='green')
plt.title('Popularity of programming language \n Worldwide Oct 2017 compared to ayear ago')
plt.xlabel('Languages')
plt.ylabel('Popularity')
plt.grid(True)
plt.show()

# %% [markdown]
# # Use the following CSV file for this exercise. Read this file using Pandas

# %%
# !wget https://pynative.com/wp-content/uploads/2019/01/company_sales_data.csv
# Out:
# --2024-07-22 09:21:36--  https://pynative.com/wp-content/uploads/2019/01/company_sales_data.csv
# Resolving pynative.com (pynative.com)... 172.66.40.219, 172.66.43.37, 2606:4700:3108::ac42:28db, ...
# Connecting to pynative.com (pynative.com)|172.66.40.219|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 659 [text/csv]
# Saving to: ‘company_sales_data.csv’
#
# company_sales_data. 100%[===================>]     659  --.-KB/s    in 0s
#
# 2024-07-22 09:21:36 (186 MB/s) - ‘company_sales_data.csv’ saved [659/659]

# %% [markdown]
# ##Exercise 1: Read Total profit of all months and show it using a line plot
#
# Total profit data provided for each month. Generated line plot must include the following properties: –
# ```
# X label name = Month Number
# Y label name = Total profit
# ```
#
# The line plot graph should look like this.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv("company_sales_data.csv")
monthno=df['month_number']
totalprofit=df['total_profit']
plt.plot(monthno,totalprofit,linestyle='-',color='blue')
plt.title('Company profit per month')
plt.xlabel('Month number')
plt.ylabel('Total profit')
plt.show()

# %% [markdown]
# ##Exercise 2: Get total profit of all months and show line plot with the following Style properties
#
# ```
# Generated line plot must include following Style properties: –
#
# Line Style dotted and Line-color should be red
# Show legend at the lower right location.
# X label name = Month Number
# Y label name = Sold units number
# Add a circle marker.
# Line marker color as read
# Line width should be 3
#
# ```
# The line plot graph should look like this.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv("company_sales_data.csv")
monthno=df['month_number']
totalprofit=df['total_profit']
plt.plot(monthno,totalprofit,linestyle=':',color='red',marker='o',markerfacecolor='red',linewidth=3,label='Profit data of last year')
plt.title('Company Sales data oflast year')
plt.xlabel('Month number')
plt.ylabel('Sold units number')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# ##Exercise 3: Read all product sales data and show it  using a multiline plot
# Display the number of units sold per month for each product using multiline plots. (i.e., Separate Plotline for each product ).
#
# The graph should look like this.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv("company_sales_data.csv")
monthno=df['month_number']
plt.plot(monthno,df['facecream'],marker='o',linestyle='-',color='blue',linewidth=3,label='Face cream Sales Data')
plt.plot(monthno,df['facewash'],marker='o',linestyle='-',color='orange',linewidth=3,label='Face Wash Sales Data')
plt.plot(monthno,df['toothpaste'],marker='o',linestyle='-',color='green',linewidth=3,label='ToothPaste Sales Data')
plt.plot(monthno,df['bathingsoap'],marker='o',linestyle='-',color='red',linewidth=3,label='Bathing soap Sales Data')
plt.plot(monthno,df['shampoo'],marker='o',linestyle='-',color='purple',linewidth=3,label='Shampoo Sales Data')
plt.plot(monthno,df['moisturizer'],marker='o',linestyle='-',color='brown',linewidth=3,label='Moisturizer Sales Data')
plt.xlabel('Month Number')
plt.ylabel('Sales unit in numbers')
plt.title('Sales data')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ##Exercise 4: Read toothpaste sales data of each month and show it using a scatter plot
# Also, add a grid in the plot. gridline style should “–“.
#
# The scatter plot should look like this.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv("company_sales_data.csv")
monthno=df['month_number']
toothpastesales=df['toothpaste']
plt.scatter(monthno,toothpastesales,label='Tooth paste sales data')
plt.xlabel('Month Number')
plt.ylabel('Number of units sold')
plt.grid(True,linestyle='--')
plt.legend()
plt.show()

# %% [markdown]
# ##Exercise 5: Read face cream and facewash product sales data and show it using the bar chart
# The bar chart should display the number of units sold per month for each product. Add a separate bar for each product in the same chart.
#
# The bar chart should look like this.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv("company_sales_data.csv")
monthno=df['month_number']
facecreamsales=df['facecream']
facewashsales=df['facewash']
monthsindices=range(len(monthno))
plt.bar(monthsindices,facecreamsales,width=0.4,label='Face cream sales data',color='blue')
plt.bar([i+0.4 for i in monthsindices],facewashsales,width=0.4,label='Face wash sales data',color='orange')
plt.xlabel('Month Number')
plt.ylabel('Sales units in number')
plt.title('Facewash and facecream sales data')
plt.xticks([i+0.4/2 for i in monthsindices],monthno)
plt.grid(True,linestyle='--')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ##Exercise 6: Read sales data of bathing soap of all months and show it using a bar chart. Save this plot to your hard disk
# The bar chart should look like this.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv("company_sales_data.csv")
monthno=df['month_number']
bathingsoapsales=df['bathingsoap']
plt.bar(monthno,bathingsoapsales,color='blue',label='bathing soap sales data')
plt.xlabel('Month Number')
plt.ylabel('Sales units in number')
plt.title('bathingsoap sales data')
plt.grid(True,linestyle='--')
plt.xticks(monthno)
plt.show()

# %% [markdown]
# ##Exercise 7: Read the total profit of each month and show it using the histogram to see the most common profit ranges
# The histogram should look like this.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv("company_sales_data.csv")
totalprofit=df['total_profit']
profitrange=[150000, 175000, 200000, 225000, 250000, 300000, 350000]
plt.hist(totalprofit,profitrange,label='profit data')
plt.title('Profit data')
plt.xlabel('profit range in dollar')
plt.ylabel('Actual profit in dollar')
plt.xticks(profitrange)
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ##Exercise 8: Calculate total sale data for last year for each product and show it using a Pie chart
# Note: In Pie chart display Number of units sold per year for each product in percentage.
#
# The Pie chart should look like this.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv("company_sales_data.csv")
totalsales = {
    'FaceCream': df['facecream'].sum(),
    'FaceWash': df['facewash'].sum(),
    'ToothPaste': df['toothpaste'].sum(),
    'BathingSoap': df['bathingsoap'].sum(),
    'Shampoo': df['shampoo'].sum(),
    'Moisturizer': df['moisturizer'].sum()
}
plt.pie(totalsales.values(),labels=totalsales.keys(),autopct='%1.1f%%')
plt.title('sales data')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# ##Exercise 9: Read Bathing soap facewash of all months and display it using the Subplot
# The Subplot should look like this.
# ![image.png](data:image/png;base64,...)

# %%
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv("company_sales_data.csv")
monthno = df['month_number']
plt.subplot(2,1,1)
plt.plot(monthno,df['bathingsoap'],color='black',linewidth=3,marker='o')
plt.title('Sales data of a bathingsoap')
plt.subplot(2,1,2)
plt.plot(monthno,df['facewash'],color='red',linewidth=3,marker='o')
plt.xlabel('Month Number')
plt.ylabel('Sales unit in number')
plt.title('Sales data of a facewash')
plt.show()

# %% [markdown]
# ##Exercise Question 10: Read all product sales data and show it using the stack plot
# The Stack plot should look like this.
#
# ![image.png](data:image/png;base64,...)

# %%
df = pd.read_csv("company_sales_data.csv")
monthno = df['month_number']
facecreamsales    = df['facecream']
facewashsales     = df['facewash']
toothpastesales   = df['toothpaste']
bathingsoapsales  = df['bathingsoap']
shampoosales      = df['shampoo']
moisturizersales  = df['moisturizer']
labels = ['face Cream','Face Wash','Tooth paste','Bathing soap','Shampoo','Moisturizer']
colors=['m','c','r','k','g','y']
plt.stackplot(monthno,facecreamsales,facewashsales,toothpastesales,bathingsoapsales,shampoosales,moisturizersales,labels=labels,colors =colors)
plt.xlabel('Month Number')
plt.ylabel('Sales unit in number')
plt.title('All products sales data using slack plot')
plt.legend(loc='upper left')
plt.show()
